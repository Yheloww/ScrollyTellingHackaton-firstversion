# %%
import pandas as pd 

df = pd.read_csv('./climate.csv')

df.head()
print(df.shape)
df['Faculties'] = df['Faculties'].dropna()
print(df.shape())
# Out:
#                                                    Name              Code  \
# 0     International Master of Science in Marine Biol...            CMIMBR
# 1     Sciences et gestion de l'environnement, à fina...          S2UENV01
# 2     Exchange Programme in Bioscience Engineering: ...            IEENTE
# 3     Master de spécialisation interdisciplinaire en...           ENVI2MC
# 4     Master of Biology AR Erasmus Mundus Joint Mast...  00397-0000001398
# ...                                                 ...               ...
# 2025  Bachelor sociaal werk aanvullingstraject na gr...       SC_54664707
# 2026  Bachelor sociaal werk verkorte leerroute na ba...       SC_52357531
# 2027  Micro degree Information Management via afstan...       SC_52388433
# 2028                    VIVES Business Academy (Spring)       SC_53860593
# 2029  Advanced bachelor International management - E...       SC_53249430
#
#                                             Faculties     School  \
# ...
